# %% [markdown]
# # subsample Analysis

# %%
import argparse
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from utils import srcc_plot_from_dataset

# %%
srcc_plot_from_dataset(curr_dataset='ml-100k', sample_mode='topk', curr_color='red')
srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='topk', curr_color='blue')
plt.title('sample_mode = topk(A non-stochastic sample method)')
plt.savefig('./box_violin_plot/srcc_sp_topk.jpg')
# plt.close()

# %%
srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='distribute', curr_color='blue')
srcc_plot_from_dataset(curr_dataset='ml-100k', sample_mode='distribute', curr_color='red')
plt.title('sample_mode = distribute(A stochastic sample method)')
plt.savefig('./box_violin_plot/srcc_sp_distribute.jpg')

# %%
srcc_plot_from_dataset(curr_dataset='ml-100k', sample_mode='topk', curr_color='red')
srcc_plot_from_dataset(curr_dataset='ml-100k', sample_mode='distribute', curr_color='green')
# srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='topk', curr_color='blue')
# srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='distribute', curr_color='blue')
plt.title('sample on ml-100k')
plt.savefig('./box_violin_plot/srcc_sp_ml-100k.jpg')

# %%
srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='distribute', curr_color='green')
srcc_plot_from_dataset(curr_dataset='ml-1m', sample_mode='topk', curr_color='red')
plt.title('sample on ml-1m')
plt.savefig('./box_violin_plot/srcc_sp_ml-1m.jpg')

# %%
import matplotlib
import random
plt_colors = list(matplotlib.colors.cnames.keys())
curr_color = random.choice(plt_colors)
# curr_color, plt_colors

# %%
import numpy as np
a = [-1,0,1,2,3,4,3,2,1]
np.max(a), np.argmax(a)
# Out:
# (4, 5)
